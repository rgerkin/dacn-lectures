# %% [markdown]
# ![xkcd-1945](https://imgs.xkcd.com/comics/scientific_paper_graph_quality.png)
#
# https://xkcd.com/1945/

# %% [markdown]
# ![tufte](http://images.nymag.com/arts/books/features/diagram070618_1_560.jpg)

# %% [markdown]
# ### http://blog.visme.co/types-of-graphs/

# %% [markdown]
# ### http://flowingdata.com/2010/01/07/11-ways-to-visualize-changes-over-time-a-guide/

# %%
# This is a shortcut to avoid having to ever do plt.show()
# %matplotlib inline

# %%
# This is the main plotting library we will use
import matplotlib.pyplot as plt
# And this is the pandas library we have been using for handling data
import pandas as pd
import numpy as np

# %%
# Make up some fake data
data = np.random.rand(100,4)+np.sin(2*np.pi*np.arange(100)/20)[:,np.newaxis]

# %%
# Let's load a simple dataset and use the date as the index
df = pd.DataFrame(data,columns=['A','B','C','D'])
df.index.name = 'Time'
df.head(10)
# Out:
#              A         B         C         D
# Time
# 0     0.358244  0.033812  0.151106  0.553117
# 1     0.400899  0.571767  0.873040  1.198109
# 2     1.511463  1.572853  1.416298  0.616352
# 3     1.427375  1.559779  1.131653  1.173568
# 4     1.137795  1.221488  1.099448  0.968446
# 5     1.776619  1.627272  1.490587  1.172881
# 6     1.300916  1.820360  1.001509  1.227632
# 7     1.253042  1.014789  1.033057  1.697637
# 8     1.552871  1.548410  1.500553  0.696363
# 9     1.308045  0.808235  0.490974  0.865076

# %% [markdown]
# ## Let's look at other plot types

# %%
# Font sizes are usually way too small!  Let's increase them.  
import matplotlib as mpl
mpl.rcParams.update({'font.size':16})

# %%
# Line plot
df.plot(ylim=(-2,6));

# %%
# Line plot
df.plot.scatter('A','B',s=50);

# %%
# Bar plot
df.iloc[:10].plot.bar(ylim=(0,3),rot=45)

# %%
# Bubble chart
df.plot.scatter('A','B',s=30*df['C']**2);

# %%
# Color Bubble chart
df.plot.scatter('A','B',s=30*df['C']**2,c=df['D']);

# %%
df.plot.hist(subplots=True,layout=(2,2),sharex=True,figsize=(7,5));
plt.tight_layout()

# %%
# Heatmap
plt.pcolor(df)
plt.xticks(np.arange(0.5,4.5),df.columns);
plt.colorbar(label='Value')

# %%
# Joint histogram
df.plot.hexbin('A','B',gridsize=10);
plt.tight_layout()

# %%
# Pie chart
df['E'] = 1*(df['A']>df['B'])
df['E'] += df['C']>df['B']
df['E'].value_counts().plot.pie()
